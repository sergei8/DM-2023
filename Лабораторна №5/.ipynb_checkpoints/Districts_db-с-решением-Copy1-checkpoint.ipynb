# %% [markdown]
# # Видобуток та збагачення структурованих даних

# %% [markdown]
# ### ТЕОРЕТИЧНА ЧАСТИНА ТА ПРИКЛАДИ

# %% [markdown]
# Для роботи з структурованими табличними даними, які розміщені в реляційній БД [SQLite](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwiUyMOv1orvAhWDK3cKHac9DyMQFjAAegQIBxAD&url=https%3A%2F%2Fru.wikipedia.org%2Fwiki%2FSQLite&usg=AOvVaw1s-RMK2VC2tXyDZxZXDYDo) в Python передбачена стандартна бібліотека [sqlite3](https://docs.python.org/3/library/sqlite3.html)

# %%
# підключення бібліотеки
import sqlite3

# %% [markdown]
# #### ПРИКЛАД ВИЛУЧЕННЯ ДАНИХ З БД
# Створити БД SQLite з ім'ям `FIT-3m`, та імпорувати в неї таблицю, що містить журнал групи `jornal`

# %%
# створюємо з'єднання з БД
conn = sqlite3.connect("FIT-3m.db")

# %% [markdown]
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %%
# створюємо об'єкт `cursor`, що відповідає за реалізацію операцій з таблицями БД
cur = conn.cursor()

# %%
print(type(cur), end='\n\n')
print(dir(cur))
# Out:
# <class 'sqlite3.Cursor'>
#
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'arraysize', 'close', 'connection', 'description', 'execute', 'executemany', 'executescript', 'fetchall', 'fetchmany', 'fetchone', 'lastrowid', 'row_factory', 'rowcount', 'setinputsizes', 'setoutputsize']

# %% [markdown]
# ##### виведемо ВСІ записи таблиці `jornal`

# %%
# створимо інстанс для операції `SELECT`
students_cur = cur.execute("SELECT * FROM jornal")

# будуємо список записів за допомогою метода `fetchall()`
students_list = students_cur.fetchall()

_ = [print(x) for x in students_list]
# Out:
# ('Колесников', 'Микита', 'M.Kolesnykov.FIT.122.20.m@knute.edu.ua')
# ('Лучук', 'Артем', 'A.Luchuk.FIT.122.20.m@knute.edu.ua')
# ('Кравченко', 'Ростислав', 'R.Kravchenko.FIT.122.20.m@knute.edu.ua')
# ('Солодкий', 'Микола', 'M.Solodkyy.FIT.122.20.m@knute.edu.ua')
# ('Причепа', 'Владислав', 'V.Prychepa.FIT.122.20.m@knute.edu.ua')
# ('Павлючик', 'Денис', 'D.Pavlyuchyk.FIT.122.20.m@knute.edu.ua')
# ('Кулініч', 'Анатолій', 'A.Kulinich.FIT.122.20.m@knute.edu.ua')

# %% [markdown]
# #### ПРИКЛАД ЗБАГАЧЕННЯ ДАНИХ З ЗОВНІШНЬОГО ДЖЕРЕЛА
#
# Додати до списка студентів їх оцінки за вступне тестування, які розташовані в csv файлі `test_result.csv`

# %% [markdown]
# імпортуємо `test_result.csv` в робочу БД як таблицю `test`
#
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %% [markdown]
# ##### Cтворимо нову таблицю, яка буде містити вміст таблиці `jornal` та поле оцінок з таблиці `test`

# %%
# створимо вираз на побудову пустої таблиці `jornal_test` з відповідними полями
sql_stmt = "CREATE TABLE IF NOT EXISTS jornal_test \
              (Surname TEXT,         \
               Name TEXT,            \
               Email TEXT,           \
               Test_result INT);"

# виконаемо запит на створення таблиці
cur.execute(sql_stmt)

# перевіримо стан виконання операції - виведемо список таблиць
tables_list = cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
tables_list.fetchall()
# Out:
# [('jornal',), ('test',), ('jornal_test',)]

# %%
# створимо запит на об'єднання таблиць 'jornal' та 'test' по прізвищу студента
sql_stmt = "SELECT jornal.*, test.\"Оцінка/100\" FROM  \
            jornal LEFT JOIN test ON jornal.Surname = test.\"Ім\'я\" "

# для перевірки виконаємо і виведемо результати запиту
cur.execute(sql_stmt).fetchall()
# Out:
# [('Колесников', 'Микита', 'M.Kolesnykov.FIT.122.20.m@knute.edu.ua', '86'),
#  ('Лучук', 'Артем', 'A.Luchuk.FIT.122.20.m@knute.edu.ua', '32'),
#  ('Кравченко', 'Ростислав', 'R.Kravchenko.FIT.122.20.m@knute.edu.ua', '50'),
#  ('Солодкий', 'Микола', 'M.Solodkyy.FIT.122.20.m@knute.edu.ua', '78'),
#  ('Причепа', 'Владислав', 'V.Prychepa.FIT.122.20.m@knute.edu.ua', '45'),
#  ('Павлючик', 'Денис', 'D.Pavlyuchyk.FIT.122.20.m@knute.edu.ua', None),
#  ('Кулініч', 'Анатолій', 'A.Kulinich.FIT.122.20.m@knute.edu.ua', '39')]

# %%
# заповнимо пусту таблицю результатми  запиту на злиття
_ = cur.execute("INSERT INTO jornal_test " + sql_stmt)

# %%
# збережемо вміст нової таблиці в список
jornal_test_list = cur.execute("SELECT * FROM jornal_test").fetchall()

_ = [print(x) for x in jornal_test_list]
# Out:
# ('Колесников', 'Микита', 'M.Kolesnykov.FIT.122.20.m@knute.edu.ua', 86)
# ('Лучук', 'Артем', 'A.Luchuk.FIT.122.20.m@knute.edu.ua', 32)
# ('Кравченко', 'Ростислав', 'R.Kravchenko.FIT.122.20.m@knute.edu.ua', 50)
# ('Солодкий', 'Микола', 'M.Solodkyy.FIT.122.20.m@knute.edu.ua', 78)
# ('Причепа', 'Владислав', 'V.Prychepa.FIT.122.20.m@knute.edu.ua', 45)
# ('Павлючик', 'Денис', 'D.Pavlyuchyk.FIT.122.20.m@knute.edu.ua', None)
# ('Кулініч', 'Анатолій', 'A.Kulinich.FIT.122.20.m@knute.edu.ua', 39)

# %%
# завершимо всі транзакції
conn.commit()

# закріємо з'єднання
conn.close()

# %% [markdown]
# #### ПРИКЛАД  ДЕСКРИПТИВНОГО АНАЛІЗУ ДАНИХ
#
# Провести [попередній аналіз](https://ru.wikipedia.org/wiki/Описательная_статистика) отриманих даних з ціллю виявленя відхилень, помилок та інших непридатних даних.

# %% [markdown]
# Сведемо результати аналізу в таблицю, яка має наступний вигляд:
#
# №| Показчик | Значення
# :--:|:-------|-------:
# 1| кількість спостережень | xx
# 2| кількість пустих значень | xx
# 4| середній бал|  xx.x
# 5| максимальний бал | xx
# 6| мінімальний бал  | xx
# 7| стандартне відхилення | xx.x
# 8| розмах вариації  | xx

# %%
# підключимо бібліотеку 'numpy' і дамо їй аліас 'np'
import numpy as np

# %% [markdown]
# ознайомитись з призначенням, можливостями та основним функціями [бібліотеки numpy](https://numpy.org)

# %%
print(dir(np))
# Out:
# ['ALLOW_THREADS', 'AxisError', 'BUFSIZE', 'CLIP', 'ComplexWarning', 'DataSource', 'ERR_CALL', 'ERR_DEFAULT', 'ERR_IGNORE', 'ERR_LOG', 'ERR_PRINT', 'ERR_RAISE', 'ERR_WARN', 'FLOATING_POINT_SUPPORT', 'FPE_DIVIDEBYZERO', 'FPE_INVALID', 'FPE_OVERFLOW', 'FPE_UNDERFLOW', 'False_', 'Inf', 'Infinity', 'MAXDIMS', 'MAY_SHARE_BOUNDS', 'MAY_SHARE_EXACT', 'MachAr', 'ModuleDeprecationWarning', 'NAN', 'NINF', 'NZERO', 'NaN', 'PINF', 'PZERO', 'RAISE', 'RankWarning', 'SHIFT_DIVIDEBYZERO', 'SHIFT_INVALID', 'SHIFT_OVERFLOW', 'SHIFT_UNDERFLOW', 'ScalarType', 'Tester', 'TooHardError', 'True_', 'UFUNC_BUFSIZE_DEFAULT', 'UFUNC_PYVALS_NAME', 'VisibleDeprecationWarning', 'WRAP', '_NoValue', '_UFUNC_API', '__NUMPY_SETUP__', '__all__', '__builtins__', '__cached__', '__config__', '__doc__', '__file__', '__git_revision__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_add_newdoc_ufunc', '_arg', '_distributor_init', '_globals', '_mat', '_pytesttester', 'abs', 'absolute', 'absolute_import', 'add', 'add_docstring', 'add_newdoc', 'add_newdoc_ufunc', 'alen', 'all', 'allclose', 'alltrue', 'amax', 'amin', 'angle', 'any', 'append', 'apply_along_axis', 'apply_over_axes', 'arange', 'arccos', 'arccosh', 'arcsin', 'arcsinh', 'arctan', 'arctan2', 'arctanh', 'argmax', 'argmin', 'argpartition', 'argsort', 'argwhere', 'around', 'array', 'array2string', 'array_equal', 'array_equiv', 'array_repr', 'array_split', 'array_str', 'asanyarray', 'asarray', 'asarray_chkfinite', 'ascontiguousarray', 'asfarray', 'asfortranarray', 'asmatrix', 'asscalar', 'atleast_1d', 'atleast_2d', 'atleast_3d', 'average', 'bartlett', 'base_repr', 'binary_repr', 'bincount', 'bitwise_and', 'bitwise_not', 'bitwise_or', 'bitwise_xor', 'blackman', 'block', 'bmat', 'bool', 'bool8', 'bool_', 'broadcast', 'broadcast_arrays', 'broadcast_to', 'busday_count', 'busday_offset', 'busdaycalendar', 'byte', 'byte_bounds', 'bytes0', 'bytes_', 'c_', 'can_cast', 'cast', 'cbrt', 'cdouble', 'ceil', 'cfloat', 'char', 'character', 'chararray', 'choose', 'clip', 'clongdouble', 'clongfloat', 'column_stack', 'common_type', 'compare_chararrays', 'compat', 'complex', 'complex128', 'complex256', 'complex64', 'complex_', 'complexfloating', 'compress', 'concatenate', 'conj', 'conjugate', 'convolve', 'copy', 'copysign', 'copyto', 'core', 'corrcoef', 'correlate', 'cos', 'cosh', 'count_nonzero', 'cov', 'cross', 'csingle', 'ctypeslib', 'cumprod', 'cumproduct', 'cumsum', 'datetime64', 'datetime_as_string', 'datetime_data', 'deg2rad', 'degrees', 'delete', 'deprecate', 'deprecate_with_doc', 'diag', 'diag_indices', 'diag_indices_from', 'diagflat', 'diagonal', 'diff', 'digitize', 'disp', 'divide', 'division', 'divmod', 'dot', 'double', 'dsplit', 'dstack', 'dtype', 'e', 'ediff1d', 'einsum', 'einsum_path', 'emath', 'empty', 'empty_like', 'equal', 'errstate', 'euler_gamma', 'exp', 'exp2', 'expand_dims', 'expm1', 'extract', 'eye', 'fabs', 'fastCopyAndTranspose', 'fft', 'fill_diagonal', 'find_common_type', 'finfo', 'fix', 'flatiter', 'flatnonzero', 'flexible', 'flip', 'fliplr', 'flipud', 'float', 'float128', 'float16', 'float32', 'float64', 'float_', 'float_power', 'floating', 'floor', 'floor_divide', 'fmax', 'fmin', 'fmod', 'format_float_positional', 'format_float_scientific', 'format_parser', 'frexp', 'frombuffer', 'fromfile', 'fromfunction', 'fromiter', 'frompyfunc', 'fromregex', 'fromstring', 'full', 'full_like', 'fv', 'gcd', 'generic', 'genfromtxt', 'geomspace', 'get_array_wrap', 'get_include', 'get_printoptions', 'getbufsize', 'geterr', 'geterrcall', 'geterrobj', 'gradient', 'greater', 'greater_equal', 'half', 'hamming', 'hanning', 'heaviside', 'histogram', 'histogram2d', 'histogram_bin_edges', 'histogramdd', 'hsplit', 'hstack', 'hypot', 'i0', 'identity', 'iinfo', 'imag', 'in1d', 'index_exp', 'indices', 'inexact', 'inf', 'info', 'infty', 'inner', 'insert', 'int', 'int0', 'int16', 'int32', 'int64', 'int8', 'int_', 'int_asbuffer', 'intc', 'integer', 'interp', 'intersect1d', 'intp', 'invert', 'ipmt', 'irr' ...

# %%
# перетворимо список студетів в numpay матрицю
jornal_test_arr = np.array(jornal_test_list)

# %%
print(jornal_test_arr)
# Out:
# [['Колесников' 'Микита' 'M.Kolesnykov.FIT.122.20.m@knute.edu.ua' 86]
#  ['Лучук' 'Артем' 'A.Luchuk.FIT.122.20.m@knute.edu.ua' 32]
#  ['Кравченко' 'Ростислав' 'R.Kravchenko.FIT.122.20.m@knute.edu.ua' 50]
#  ['Солодкий' 'Микола' 'M.Solodkyy.FIT.122.20.m@knute.edu.ua' 78]
#  ['Причепа' 'Владислав' 'V.Prychepa.FIT.122.20.m@knute.edu.ua' 45]
#  ['Павлючик' 'Денис' 'D.Pavlyuchyk.FIT.122.20.m@knute.edu.ua' None]
#  ['Кулініч' 'Анатолій' 'A.Kulinich.FIT.122.20.m@knute.edu.ua' 39]]

# %%
print(type (jornal_test_arr), jornal_test_arr.shape)
# Out:
# <class 'numpy.ndarray'> (7, 4)

# %%
# створимо масив с результатами тестів 
test_result = np.delete(jornal_test_arr, [0,1,2], 1)

# %%
# Значення 'None' - не є числом, то заміним його на 0
test_result[test_result == None] = 0

# %%
# будуємо словник з вихідними розрахунками
result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : np.count_nonzero(test_result == 0),
    "середній бал"             : np.mean(test_result),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : np.std(test_result),
    "розмах вариації"          : result_dict["максимальний бал"] - result_dict["мінімальний бал"] 
    }

# %%
result_dict
# Out:
# {'кількість спостережень': 7,
#  'кількість пустих значень': 1,
#  'середній бал': 47.142857142857146,
#  'максимальний бал': 86,
#  'мінімальний бал': 32,
#  'стандартне відхилення': 26.70702727977131,
#  'розмах вариації': 54}

# %%
# вивести шапку
print(
"""
=======================================
№  : ПОКАЗЧИК               : ЗНАЧЕННЯ     
=======================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1
# Out:
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     7
# 2   кількість пустих значень   1
# 3   середній бал               47.142857142857146
# 4   максимальний бал           86
# 5   мінімальний бал            32
# 6   стандартне відхилення      26.70702727977131
# 7   розмах вариації            54

# %% [markdown]
# ### ІНДИВІДУАЛЬНЕ ЗАВДАННЯ

# %% [markdown]
# Користуючись результатами, що отримані в [Лабораторній роботі № 3](https://shkliarskiy.moodlecloud.com/mod/page/view.php?id=1193) виконати процедури видобутку, збагачення та попереднього аналізу даних.
#
# __Постановка__: В 3-й лабораторній роботі отримано показчик, що характеризує окрему властивість квартири (ціна, метраж та ін.).
# Необхідно:
# 1. Відобразити цей показчик на адресу квартири, яка знаходиться в файлі `street_name.csv`, тобто побудувати новий файл `street_flat_propery.csv` якій містить 2 колонки: _<назва вулиці> <ваш показчик>_
# 2. На основі цьго файлу зробити відповідну таблицю в _SQLite_ та збагатити цю дані в цій таблиці назвою району де розташована квартира (дані по районах додаються)
# 3. Провести попередній аналіз отриманих даних - вивести первинні статистики показчика по районах (_середне_ , _мінімальне_ , _максимальне_ і т.д. - див. приклад вище)

# %%
# Злиття файлу з показчиком та файлу з назвами вулиць в новий файл

# YOUR_FILE = підставте ваш файл ...
YOUR_FILE = 'total_price.csv'
with open(YOUR_FILE) as f1, \
     open('street_name.csv') as f2, \
     open('street_flat_propery.csv', 'w') as f3:
    
    for x, y in zip(f1, f2):
        line = f'{x[:-1].strip()},{y[:-1].strip()}\n'
        print(line)
        f3.write(line)
# Out:
# price,Street-Name
#
# 140000.0,Омеляновича-Павленка
#
# 105000.0,
#
# 175000.0,Ованеса Туманяна
#
# 30970.0,Петропавлівська
#
# 82000.0,Дніпровська
#
# 168535.7,Саксаганського
#
# 4500000.0,Івана Мазепи
#
# 135000.0,Дніпровська
#
# 120000.0,Ділова
#
# 57500.0,Новодарницька
#
# 98000.0,Ревуцького
#
# 170000.0,Липківського
#
# 320000.0,Бендукідзе
#
# 65000.0,Введенська
#
# 125000.0,Виноградний
#
# 48000.0,Кайсарова
#
# 70000.0,Ахматової
#
# 75000.0,Радченка
#
# 84000.0,Дніпровська
#
# 175000.0,Ділова
#
# 63000.0,Бориспільська
#
# 390000.0,Болсуновська
#
# 335000.0,Українки
#
# 320000.0,Антонова
#
# 140000.0,Омеляновича-Павленка
#
# 105000.0,
#
# 175000.0,Ованеса Туманяна
#
# 30970.0,Петропавлівська
#
# 82000.0,Дніпровська
#
# 168535.7,Саксаганського
#
# 4500000.0,Івана Мазепи
#
# 135000.0,Дніпровська
#
# 120000.0,Ділова
#
# 57500.0,Новодарницька
#
# 98000.0,Ревуцького
#
# 170000.0,Липківського
#
# 320000.0,Бендукідзе
#
# 65000.0,Введенська
#
# 125000.0,Виноградний
#
# 48000.0,Кайсарова
#
# 70000.0,Ахматової
#
# 75000.0,Радченка
#
# 84000.0,Дніпровська
#
# 175000.0,Ділова
#
# 63000.0,Бориспільська
#
# 390000.0,Болсуновська
#
# 335000.0,Українки
#
# 320000.0,Антонова
#
# 118000.0,Науки
#
# 159990.0,Метрологічна
#
# 85000.0,Дружби Народів
#
# 155022.2,*** not found
#
# 590000.0,Драгомирова
#
# 84000.0,Данченка
#
# 35000.0,Кримська
#
# 63000.0,Новопольова
#
# 40000.0,Туполєва
#
# 42654.8,*** not found
#
# 60000.0,Дніпровська
#
# 130000.0,Перемоги
#
# 346500.0,Івана Федорова
#
# 46998.0,Братиславська
#
# 10092.1,*** not found
#
# 29256.6,Червоноткацька
#
# 166000.0,Златоустівська
#
# 115000.0,Бойченка
#
# 298000.0,Трускавецька
#
# 43100.0,Каховська
#
# 179900.0,Лобановського
#
# 96255.3,*** not found
#
# 56500.0,Курчатова
#
# 110000.0,Голосіївська
#
# 47000.0,Тираспольська
#
# 90000.0,Лаврська
#
# 44980.0,Правди
#
# 58000.0,Миколайчука
#
# 63000.0,Порика
#
# 29256.6,Червоноткацька
#
# 136000.0,Маккейна
#
# 73860.0,Йорданська
#
# 160000.0,Тютюнника
#
# 135000.0,Регенераторна
#
# 120000.0,Зарічна
#
# 58990.0,Заболотного
#
# 90000.0,Курнатовського
#
# 187000.0,Інститутська
#
# 88000.0,Маланюка
#
# 102000.0,Гречка
#
# 110000.0,Липківського
#
# 160000.0,Маккейна
#
# 225000.0,Григоренка
#
# 75000.0,Коновальця
#
# 59860.0,Закревського
#
# 43161.0,*** not found
#
# 140000.0,Старонаводницька
#
# 78000.0,Маланюка
#
# 230000.0,Заньковецької
#
# 178000.0,Кудрявська
#
# 63000.0,
#
# 495000.0,Українки
#
# 45900.0,
#
# 33000.0,Милославська
#
# 66500.0,Донця
#
# 119900.0,Верховинця
#
# 145000.0,Героїв Дніпра
#
# 118000.0,Каховська
#
# 41000.0,Каховська
#
# 59899.0,Вишняківська
#
# 177000.0,Липська
#
# 63000.0,Сверстюка
#
# 499000.0,Драгомирова
#
# 49500.0,Причальна
#
# 275000.0,Болсуновська
#
# 93000.0,Повітрофлотський
#
# 87500.0,Драгоманова
#
# 110000.0,Григоренка
#
# 900000.0,Дніпровська
#
# 86000.0,Жабаєва
#
# 335000.0,Філатова
#
# 67000.0,Правди
#
# 90000.0,Малопідвальна
#
# 101500.0,Бойчука
#
# 104000.0,Зарічна
#
# 190000.0,Предславинська
#
# 3600000.0,Івана Мазепи
#
# 63000.0,Радченка
#
# 680000.0,Лабораторний
#
# 139000.0,Конєва
#
# 347700.0,Шаповала
#
# 85000.0,Дніпровська
#
# 35600.0,Клеманська
#
# 85000.0,Григоренка
#
# 46000.0,Туполєва
#
# 125000.0,Хмельницького
#
# 530000.0,Саперне Поле
#
# 229000.0,Героїв Сталінграда
#
# 117000.0,Дніпровська
#
# 110000.0,Тарасівська
#
# 92900.0,Краківська
#
# 77500.0,Юнацька
#
# 40500.0,Клеманська
#
# 136000.0,Героїв Сталінграда
#
# 499000.0,Драгомирова
#
# 220000.0,*** not found
#
# 125000.0,Драгоманова
#
# 100000.0,Українки
#
# 80000.0,Тимошенка
#
# 57000.0,Маяковського
#
# 170000.0,Дмитрівська
#
# 59750.0,Курбаса
#
# 42678.6,Комарова
#
# 92000.0,Драгоманова
#
# 115000.0,Драгомирова
#
# 54000.0,Моторний
#
# 45500.0,Милославська
#
# 91500.0,Бойчука
#
# 60500.0,Закревського
#
# 250000.0,Івана Федорова
#
# 78000.0,Філатова
#
# 130000.0,Перемоги
#
# 84999.0,Миропільська
#
# 83000.0,Григоренка
#
# 129999.0,Юнацька
#
# 70000.0,Вишгородська
#
# 36000.0,Жолудєва
#
# 210000.0,Павлівська
#
# 85900.0,Голосіївський
#
# 108000.0,Осокорська
#
# 120000.0,Вишгородська
#
# 221000.0,Драгомирова
#
# 60000.0,Тютюнника
#
# 165000.0,Маккейна
#
# 200000.0,Івана Мазепи
#
# 145000.0,Героїв Сталінграда
#
# 199000.0,Липківського
#
# 186117.4,*** not found
#
# 199000.0,Коновальця
#
# 50700.0,Максимовича
#
# 185000.0,Зарічна
#
# 152000.0,Голосіївська
#
# 92000.0,Ясинуватський
#
# 49387.4,*** not found
#
# 56500.0,Колоса
#
# 80000.0,Правди
#
# 480000.0,Велика Васильківська
#
# 59000.0,Голосіївський
#
# 149632.1,*** not found
#
# 147075.0,Бойчука
#
# 86860.0,Центральна
#
# 97000.0,Ясинуватський
#
# 55000.0,Райдужна
#
# 138000.0,Ломоносова
#
# 105000.0,
#
# 66016.1,*** not found
#
# 284000.0,Гусовського
#
# 155000.0,Окіпної
#
# 49899.0,Багговутівська
#
# 95000.0,Дружби Народів
#
# 380000.0,Маккейна
#
# 46000.0,Маланюка
#
# 60150.0,Михайла Котельникова
#
# 185000.0,Героїв Севастополя
#
# 81000.0,Маланюка
#
# 620000.0,Саперне Поле
#
# 48700.0,Балтійський
#
# 234000.0,Кудрявська
#
# 135000.0,Перемоги
#
# 130000.0,Німанська
#
# 54100.0,Каховська
#
# 239000.0,Малопідвальна
#
# 140000.0,Невська
#
# 128000.0,Златоустівська
#
# 31000.0,
#
# 41187.0,Берковецька
#
# 120000.0,Бажана
#
# 740000.0,Антоновича
#
# 180000.0,*** not found
#
# 63000.0,Гречка
#
# 126000.0,Микільсько-Слобідська
#
# 80000.0,Правди
#
# 98000.0,Тимошенка
#
# 150000.0,Павла Тичини
#
# 100000.0,Олевська
#
# 120000.0,Освіти
#
# 41000.0,Іллєнка
#
# 135000.0,Дніпровська
#
# 155000.0,Івана Мазепи
#
# 90000.0,Українки
#
# 132000.0,Данченка
#
# 230000.0,Драгомирова
#
# 185000.0,Тбіліський
#
# 70500.0,Каховська
#
# 87000.0,Ушинського
#
# 185000.0,Урлівська
#
# 49860.0,Світлицького
#
# 100000.0,Дніпровська
#
# 90000.0,Липківського
#
# 152000.0,Микільсько-Слобідська
#
# 159900.0,Лобановського
#
# 280000.0,Героїв Сталінграда
#
# 85000.0,Дніпровська
#
# 67000.0,Драгоманова
#
# 59000.0,Ахматової
#
# 420000.0,Саперне Поле
#
# 65000.0,Данченка
#
# 63000.0,Голосіївський
#
# 95000.0,*** not found
#
# 100000.0,Глибочицька
#
# 165000.0,Багговутівська
#
# 150000.0,Саксаганського
#
# 64000.0,Моторний
#
# 73860.0,Йорданська
#
# 295000.0,Саперне Поле
#
# 55000.0,Вернадського
#
# 79900.0,Курбаса
#
# 100000.0,Багговутівська
#
# 122000.0,Набережно-Рибальська
#
# 145000.0,Саксаганського
#
# 133000.0,Малиновського
#
# 143000.0,Протасів Яр
#
# 62000.0,Німанська
#
# 95000.0,Підвисоцького
#
# 38000.0,Зодчих
#
# 52500.0,Рокосовського
#
# 229000.0,Шовковична
#
# 62000.0,Крушельницької
#
# 70000.0,Новопольова
#
# 45000.0,Визволителів
#
# 70000.0,Сонячна
#
# 158000.0,Сікорського
#
# 58900.0,Радченка
#
# 104700.0,Бульварно-Кудрявська
#
# 37000.0,Кайсарова
#
# 85000.0,Дніпровська
#
# 46000.0,Перова
#
# 150000.0,Глушкова
#
# 52500.0,Рокосовського
#
# 120000.0,Саперно-Слобідська
#
# 38000.0,Миколи Кибальчича
#
# 45000.0,Миколи Ушакова
#
# 250000.0,Антоновича
#
# 185000.0,Богданівська
#
# 68000.0,
#
# 57000.0,Сверстюка
#
# 52500.0,Ревуцького
#
# 250000.0,Ованеса Туманяна
#
# 540000.0,Саперне Поле
#
# 120000.0,Григоренка
#
# 55999.0,Гречка
#
# 68800.0,Богатирська
#
# 120000.0,Білоруська
#
# 94000.0,Регенераторна
#
# 65500.0,Вишняківська
#
# 50000.0,Гонгадзе
#
# 52500.0,Правди
#
# 64980.0,Кольцова
#
# 115000.0,Воскресенська
#
# 200000.0,Руставелі
#
# 484000.0,Голосіївський
#
# 79000.0,Комбінатна
#
# 45000.0,Салютна
#
# 78000.0,Маланюка
#
# 91999.0,Ромоданова
#
# 128000.0,Саперне Поле
#
# 38700.0,Сім’ї Кульженків
#
# 95000.0,Лабораторна
#
# 77000.0,Драгоманова
#
# 52990.0,
#
# 330000.0,Кудрявська
#
# 83000.0,Краківська
#
# 105000.0,Кольцова
#
# 225000.0,Антоновича
#
# 62000.0,Лариси Руденко
#
# 90000.0,Івана Пулюя
#
# 215000.0,Українки
#
# 137000.0,Тютюнника
#
# 36000.0,Юрія Смолича
#
# 195000.0,Оболонський
#
# 60000.0,Курбаса
#
# 87000.0,Верховинця
#
# 185000.0,Зарічна
#
# 210000.0,Дніпровська
#
# 135000.0,Коломийський
#
# 84000.0,Правди
#
# 160000.0,Каховська
#
# 292000.0,Бойчука
#
# 53000.0,Правди
#
# 115000.0,Маккейна
#
# 90900.0,Перемоги
#
# 2100000.0,Грушевського
#
# 980000.0,Срібнокільська
#
# 91260.0,Перемоги
#
# 118000.0,Урлівська
#
# 84100.0,Заболотного
#
# 79700.0,Максимовича
#
# 220000.0,Бажана
#
# 155000.0,Сікорського
#
# 40000.0,Курбаса
#
# 68500.0,Дніпровська
#
# 720000.0,Драгомирова
#
# 64000.0,
#
# 44000.0,Антонова
#
# 63000.0,Бучми
#
# 64500.0,Кубанської України
#
# 100000.0,Дніпровська
#
# 249999.0,Панельна
#
# 270000.0,Коновальця
#
# 52000.0,Богатирська
#
# 50000.0,Оболонський
#
# 465000.0,Українки
#
# 125000.0,Бориса Гмирі
#
# 84000.0,Правди
#
# 69000.0,Центральна
#
# 70000.0,Преображенська
#
# 260000.0,Коновальця
#
# 124860.0,Українки
#
# 135000.0,*** not found
#
# 170000.0,Велика Васильківська
#
# 84000.0,Липківського
#
# 612500.0,Бойчука
#
# 46500.0,Васильківська
#
# 129000.0,Данькевича
#
# 89332.9,Богатирська
#
# 99000.0,Українки
#
# 117000.0,Гречка
#
# 1035900.0,Редутна
#
# 132000.0,Бориса Гмирі
#
# 340000.0,Драгомирова
#
# 31000.0,Туполєва
#
# 55000.0,Кондратюка
#
# 43000.0,Мінський
#
# 235000.0,Княжий Затон
#
# 105900.0,Герцена
#
# 49700.0,Балтійський
#
# 110000.0,Ернста
#
# 275000.0,Шаповала
#
# 220000.0,Городецького
#
# 30000.0,Сім'ї Сосніних
#
# 140000.0,Івана Мазепи
#
# 132500.0,Червоноткацька
#
# 50000.0,*** not found
#
# 225000.0,Голосіївська
#
# 165000.0,*** not found
#
# 65000.0,Миколи Гулака
#
# 230000.0,Івана Федорова
#
# 205000.0,Саперне Поле
#
# 33071.4,Миколи Хвильового
#
# 777500.0,Паторжинського
#
# 128500.0,Наумовича
#
# 80000.0,Калнишевського
#
# 100500.0,Дніпровська
#
# 149000.0,Електриків
#
# 95000.0,Солом'янська
#
# 159000.0,Шевченка
#
# 68000.0,Озерна
#
# 89400.0,Григоренка
#
# 330000.0,Антонова
#
# 229000.0,Голосіївський
#
# 67000.0,Комарова
#
# 66500.0,Борщагівська
#
# 480000.0,Шевченка
#
# 74000.0,Максимовича
#
# 175000.0,Ковальський
#
# 159000.0,Малевича
#
# 3200000.0,Мічуріна
#
# 380000.0,*** not found
#
# 63000.0,Балтійський
#
# 85000.0,Азербайджанська
#
# 130032.0,Зарічна
#
# 95700.0,Чавдар
#
# 50000.0,Правди
#
# 114900.0,Урлівська
#
# 41500.0,Бориспільська
#
# 125000.0,Поправки
#
# 48000.0,Бориспільська
#
# 59899.0,Ентузіастів
#
# 83000.0,Малоземельна
#
# 335000.0,Саксаганського
#
# 98500.0,Героїв Сталінграда
#
# 58000.0,Зодчих
#
# 52000.0,Калнишевського
#
# 195000.0,Філатова
#
# 345000.0,Старонаводницька
#
# 89900.0,Заболотного
#
# 58000.0,Правди
#
# 66500.0,*** not found
#
# 290000.0,Антоновича
#
# 380000.0,Шаповала
#
# 230000.0,Івана Федорова
#
# 135000.0,Деревлянська
#
# 165000.0,Вільямса
#
# 107000.0,Васильченка
#
# 139990.0,Предславинська
#
# 31000.0,Крайня
#
# 58000.0,Милославська
#
# 145000.0,Воскресенська
#
# 67900.0,Маланюка
#
# 230000.0,Дніпровська
#
# 240000.0,Пушкінська
#
# 65280.0,Набережно-Корчуватська
#
# 150000.0,Зарічна
#
# 499990.0,Тургенєвська
#
# 66624.0,Радченка
#
# 140000.0,Зарічна
#
# 68900.0,Метрологічна
#
# 73860.0,Йорданська
#
# 49500.0,Кольцова
#
# 138000.0,Максимовича
#
# 55500.0,Науки
#
# 206000.0,Саперно-Слобідська
#
# 110000.0,Шовковична
#
# 250000.0,Трускавецька
#
# 59157.0,Гавела
#
# 53000.0,Повітрофлотський
#
# 58000.0,Запорожця
#
# 177000.0,Маккейна
#
# 86000.0,Перемоги
#
# 70000.0,Щербаківського
#
# 73000.0,Зарічна
#
# 45000.0,Будищанська
#
# 115000.0,Жилянська
#
# 79000.0,Комбінатна
#
# 88000.0,Ревуцького
#
# 29900.0,Бородіна
#
# 189000.0,Руставелі
#
# 95000.0,Драгоманова
#
# 128000.0,Преображенська
#
# 68000.0,Депутатська
#
# 85000.0,Багговутівська
#
# 160000.0,*** not found
#
# 135000.0,Сікорського
#
# 800000.0,Драгомирова
#
# 250000.0,Коперніка
#
# 127000.0,Васильківська
#
# 98000.0,Глибочицька
#
# 125000.0,Чавдар
#
# 229000.0,Шовковична
#
# 115000.0,Дніпровська
#
# 90000.0,Антоновича
#
# 56000.0,
#
# 53000.0,Славгородська
#
# 250000.0,Драгомирова
#
# 205000.0,Срібнокільська
#
# 59950.0,Харченка
#
# 250000.0,Окіпної
#
# 205000.0,Саперне Поле
#
# 38500.0,Олени Теліги
#
# 99999.0,Кондратюка
#
# 120000.0,Мечнікова
#
# 150000.0,Героїв Сталінграда
#
# 285000.0,Рибальська
#
# 72500.0,Березова
#
# 750000.0,Саперне Поле
#
# 493000.0,Антоновича
#
# 290000.0,Маккейна
#
# 247000.0,Лейпцизька
#
# 90000.0,Драгоманова
#
# 80000.0,Коновальця
#
# 103900.0,Василя Стуса
#
# 265000.0,Тютюнника
#
# 105000.0,Січових Стрільців
#
# 78000.0,Райдужна
#
# 44900.0,Закревського
#
# 494000.0,Тургенєвська
#
# 46500.0,Васильківська
#
# 55000.0,Зої Космодем'янської
#
# 59280.0,Радченка
#
# 56000.0,Сверстюка
#
# 47500.0,Милославська
#
# 100000.0,Метрологічна
#
# 103000.0,Деміївська
#
# 95000.0,Перемоги
#
# 76800.0,Вишгородська
#
# 257500.0,Маккейна
#
# 52500.0,
#
# 302200.0,Перемоги
#
# 63500.0,Балтійський
#
# 550000.0,Звіринецька
#
# 98700.0,Ревуцького
#
# 80000.0,Правди
#
# 35000.0,Милославська
#
# 56000.0,Вербицького
#
# 36000.0,Новгородська
#
# 87000.0,Бажана
#
# 220000.0,Канівська
#
# 109000.0,Максимовича
#
# 125000.0,Донця
#
# 600000.0,Драгомирова
#
# 60000.0,Тираспольська
#
# 15700000.0,Саксаганського
#
# 45000.0,Тираспольська
#
# 160000.0,Зарічна
#
# 65000.0,Гонгадзе
#
# 495000.0,Українки
#
# 59000.0,Світлицького
#
# 68000.0,Воробйова
#
# 81000.0,Каховська
#
# 67000.0,Глибочицька
#
# 170000.0,Білокур
#
# 54500.0,Балтійський
#
# 232000.0,Антоновича
#
# 75000.0,Кондратюка
#
# 99000.0,Гончара
#
# 55000.0,Ревуцького
#
# 475000.0,*** not found
#
# 70000.0,Драгоманова
#
# 79900.0,Сім’ї Кульженків
#
# 215767.9,Панельна
#
# 155000.0,Вільямса
#
# 100000.0,Голосіївська
#
# 1010000.0,Оболонський
#
# 45000.0,Миколи Голего
#
# 80000.0,Дніпровська
#
# 115000.0,Малиновського
#
# 620000.0,Назарівська
#
# 250500.0,Гоголівська
#
# 39000.0,Дорогожицька
#
# 30970.0,Петропавлівська
#
# 360000.0,Грушевського
#
# 250000.0,Іллєнка
#
# 95000.0,Липківського
#
# 63900.0,Ушинського
#
# 81000.0,Польова
#
# 219000.0,Саперне Поле
#
# 162000.0,Панельна
#
# 199000.0,Коновальця
#
# 260000.0,Хмельницького
#
# 163000.0,Маккейна
#
# 499000.0,Антоновича
#
# 310000.0,Толстого
#
# 99800.0,Дружби Народів
#
# 130000.0,Оболонський
#
# 70000.0,Багговутівська
#
# 44500.0,Антонова
#
# 199000.0,Володимирська
#
# 120000.0,Українки
#
# 68750.0,Сім’ї Кульженків
#
# 162000.0,Коновальця
#
# 209000.0,Мирного
#
# 275000.0,Московська
#
# 38000.0,Жмеринська
#
# 114000.0,Бойчука
#
# 161000.0,Липківського
#
# 330000.0,Лабораторний
#
# 1500000.0,Інститутська
#
# 99000.0,Українки
#
# 295000.0,Хрещатик
#
# 62000.0,Дніпровська
#
# 108000.0,Осокорська
#
# 255000.0,Саперне Поле
#
# 68000.0,Комарова
#
# 164000.0,Драгомирова
#
# 139000.0,Срібнокільська
#
# 115000.0,Чоколівський
#
# 104000.0,Звіринецька
#
# 85000.0,Вишгородська
#
# 190000.0,Драгомирова
#
# 229000.0,Героїв Сталінграда
#
# 65000.0,Будівельників
#
# 250000.0,Іллєнка
#
# 105000.0,Урлівська
#
# 57000.0,Сормовська
#
# 65000.0,Правди
#
# 98000.0,Верховинна
#
# 55000.0,Вербицького
#
# 55000.0,*** not found
#
# 115000.0,Велика Васильківська
#
# 158364.0,Бойчука
#
# 80000.0,Лобановського
#
# 41000.0,Миколи Шепелєва
#
# 435000.0,Кропивницького
#
# 100000.0,Трускавецька
#
# 110000.0,Голосіївська
#
# 88107.1,Маланюка
#
# 130000.0,Драгомирова
#
# 125000.0,Юнацька
#
# 89000.0,Максимовича
#
# 110000.0,Комарова
#
# 70000.0,Багговутівська
#
# 46000.0,
#
# 84000.0,Костанайська
#
# 160000.0,Срібнокільська
#
# 42000.0,Курчатова
#
# 61000.0,Гусовського
#
# 130000.0,Українки
#
# 120000.0,Драгоманова
#
# 250000.0,Дніпровська
#
# 125000.0,Заболотного
#
# 79235.0,Заболотного
#
# 113261.0,Перемоги
#
# 62000.0,Сверстюка
#
# 131000.0,Липківського
#
# 300000.0,Маккейна
#
# 108000.0,Дніпровська
#
# 47000.0,Волгоградська
#
# 57000.0,Новопольова
#
# 135482.1,Драгоманова
#
# 149000.0,Лебедєва
#
# 85000.0,*** not found
#
# 123900.0,Драгомирова
#
# 150000.0,Лейпцизька
#
# 285000.0,Глибочицька
#
# 115000.0,Салютна
#
# 45900.0,Метрологічна
#
# 60000.0,Північно-Сирецька
#
# 115000.0,Правди
#
# 44000.0,Вернадського
#
# 85000.0,Пчілки
#
# 183693.7,Лейпцизька
#
# 200000.0,Басейна
#
# 138000.0,Шаповала
#
# 39500.0,Бережанська
#
# 123500.0,Бойчука
#
# 80000.0,Перемоги
#
# 1976000.0,Івана Федорова
#
# 320000.0,Антоновича
#
# 110000.0,Вільямса
#
# 92000.0,Бойчука
#
# 101000.0,Перемоги
#
# 849000.0,Ковпака
#
# 85000.0,Русанівський
#
# 330000.0,Українки
#
# 33900.0,Празька
#
# 165000.0,Гончара
#
# 270000.0,Маккейна
#
# 40000.0,Балтійський
#
# 104000.0,Білоруська
#
# 75000.0,Драгоманова
#
# 115000.0,Липківського
#
# 58000.0,Новогоспітальна
#
# 30540.0,Радченка
#
# 259999.0,Богомольця
#
# 140000.0,Донця
#
# 160000.0,Оболонський
#
# 200714.3,Щекавицька
#
# 65000.0,Пожарського
#
# 74000.0,Полкова
#
# 66500.0,Донця
#
# 67000.0,Палладіна
#
# 110000.0,Бойчука
#
# 127000.0,Липківського
#
# 180000.0,Павлівська
#
# 63000.0,Івашкевича
#
# 42900.0,Іскрівська
#
# 95000.0,Максимовича
#
# 255000.0,*** not found
#
# 100357.1,Драгомирова
#
# 115000.0,Теремківська
#
# 113300.0,Осокорська
#
# 268000.0,Дмитрівська
#
# 140000.0,Кондратюка
#
# 146000.0,Регенераторна
#
# 63000.0,
#
# 495000.0,Глибочицька
#
# 275000.0,Героїв Сталінграда
#
# 73500.0,Борщагівська
#
# 57000.0,Ревуцького
#
# 121860.0,Юнацька
#
# 73000.0,Заболотного
#
# 39000.0,Автозаводська
#
# 92284.0,Заболотного
#
# 210000.0,Саксаганського
#
# 139900.0,Зарічна
#
# 145000.0,*** not found
#
# 140000.0,Невська
#
# 76000.0,Героїв Сталінграда
#
# 65500.0,Вишняківська
#
# 796000.0,Драгомирова
#
# 97926.0,Драгомирова
#
# 46000.0,Гавела
#
# 115000.0,Здолбунівська
#
# 430000.0,Драгомирова
#
# 3210000.0,Мечнікова
#
# 475000.0,*** not found
#
# 127900.0,Максимовича
#
# 75000.0,Багговутівська
#
# 90005.0,Шолуденка
#
# 284999.0,Щекавицька
#
# 51000.0,Коласа
#
# 320000.0,*** not found
#
# 43000.0,*** not found
#
# 91000.0,Перемоги
#
# 185000.0,*** not found
#
# 49990.0,Наумова
#
# 89000.0,Перемоги
#
# 170000.0,Велика Васильківська
#
# 29256.6,Червоноткацька
#
# 46500.0,Вишгородська

# %% [markdown]
# #### імпортувати в БД файл 'street_flat_propery.csv' через CLI
# - __sqlite3 districts.db__ - запустити SQLite та відкрити БД
# - __.mode csv__ - перевести БД для роботи з csv-файлами
# - __.import street_flat_propery.csv street_flat_propery__ - створює таблицю _street_flat_propery_ та завантажує в неї вміст файлу _street_flat_propery.csv_
# - __SELECT * FROM street_flat_propery LIMIT 10;__ - вивести 10 записів для перевірки
# - __.quit__ - завершити роботу з CLI SQLite

# %%
# Підключитись до БД 'districts.db' та створити відповідний курсор
conn = напишить код ...
cur  = напишить код ...

# %%
# для перевірки виведіть виведіть 10 записів з таблиці 'street_district'
напишить код ...

# %%
# побудувати запит на створення таблиці 'result' з 3-ма полями:
#     district - текстове
#     street - текстове
#     property - числове
stmt = напишить код ...

# %%
# виконати запит
cur.execute(stmt)

# %%
# перевірити схему таблиці
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('result');").fetchall()
# Out:
# [('district',), ('street',), ('price',)]

# %%
# створити запит на злиття таблиці 'street_flat_propery' та 'street_district' 
# по полю 'street'
stmt_join = напишить код ...

# %%
# перевірити запит
cur.execute(stmt_join).fetchall()

# %%
# створити запит для наповнення таблиці `result` результатом запиту на об'єднання
stmt_insert = напишить код ..

# %%
# виконати запит на заповнення
cur.execute(stmt_insert)

# %%
# сберегти вміст створеної таблиці у вигляді списка
result_list = напишить код ...

# %% [markdown]
# #### для аналізу скористатися бібліотекою NumPy

# %%
import numpy as np

# %%
# створити np-масив з списку `result_list`
result_arr = напишить код ...

# %%
# побудувати словник для результатів аналізу
result_dict = {
    "кількість спостережень"   : напишить код ... ,
    "середнє значення"         : напишить код ... ,
    "максимальне значення"     : напишить код ... ,
    "мінімальне значення"      : напишить код ... ,
    "стандартне відхилення"    : напишить код ... ,
    "розмах вариації"          : напишить код ...
    }

# %%
# вивести шапку
print(
"""
================================================
№  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ     
================================================
"""      
      )

# вивести результати аналізу датасета
напишить код ...

# %%
conn = sqlite3.connect("districts.db")
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM street_district LIMIT 10;").fetchall()
# Out:
# [('9-го Травня', 'вулиця', 'Святошинський'),
#  ('Абрикосова', 'вулиця', 'Оболонський'),
#  ('Абрикосова', 'вулиця', 'Дарницький'),
#  ('Абрикосова', 'вулиця', 'Подільський'),
#  ('Августина Волошина', 'вулиця', 'Солом’янський'),
#  ('Авдєєнка Генерала', 'вулиця', 'Святошинський'),
#  ('Автозаводська', 'вулиця', 'Оболонський'),
#  ('Автозаводський ', 'провулок', 'Оболонський'),
#  ('Автопаркова', 'вулиця', 'Дарницький'),
#  ('Авторемонтна', 'вулиця', "Солом'янський")]

# %%
stmt = "CREATE TABLE result (district TEXT, street TEXT, price INT);"
cur.execute(stmt)

# %%
cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';").fetchall()
# Out:
# [('street_district',), ('street_flat_propery',), ('result',)]

# %%
stmt_join = \
"SELECT street_flat_propery.street, street_district.district, street_flat_propery.price \
FROM street_flat_propery \
JOIN street_district ON street_flat_propery.street == street_district.street;"

# %%
stmt_join
# Out:
# 'SELECT street_flat_propery.street, street_district.district, street_flat_propery.price FROM street_flat_propery JOIN street_district ON street_flat_propery.street == street_district.street;'

# %%
stmt_insert = "INSERT INTO result " + stmt_join

# %%
cur.execute(stmt_insert)

# %%
cur.execute("SELECT * FROM result LIMIT 10; ").fetchall()
# Out:
# [('Петропавлівська', 'Оболонський', 30970),
#  ('Петропавлівська', 'Подільський', 30970),
#  ('Дніпровська', 'Оболонський', 82000),
#  ('Саксаганського', 'Голосіївський, Печерський, Шевченківський', 168535.7),
#  ('Дніпровська', 'Оболонський', 135000),
#  ('Ділова', 'Голосіївський, Печерський', 120000),
#  ('Ревуцького', 'Дарницький', 98000),
#  ('Введенська', 'Подільський', 65000),
#  ('Виноградний', 'Печерський', 125000),
#  ('Кайсарова', "Голосіївський,Солом'янський", 48000)]

# %%
result_list = cur.execute("SELECT * FROM result;").fetchall()
result_list
# Out:
# [('Петропавлівська', 'Оболонський', 30970),
#  ('Петропавлівська', 'Подільський', 30970),
#  ('Дніпровська', 'Оболонський', 82000),
#  ('Саксаганського', 'Голосіївський, Печерський, Шевченківський', 168535.7),
#  ('Дніпровська', 'Оболонський', 135000),
#  ('Ділова', 'Голосіївський, Печерський', 120000),
#  ('Ревуцького', 'Дарницький', 98000),
#  ('Введенська', 'Подільський', 65000),
#  ('Виноградний', 'Печерський', 125000),
#  ('Кайсарова', "Голосіївський,Солом'янський", 48000),
#  ('Дніпровська', 'Оболонський', 84000),
#  ('Ділова', 'Голосіївський, Печерський', 175000),
#  ('Бориспільська', 'Дарницький', 63000),
#  ('Болсуновська', 'Печерський', 390000),
#  ('Петропавлівська', 'Оболонський', 30970),
#  ('Петропавлівська', 'Подільський', 30970),
#  ('Дніпровська', 'Оболонський', 82000),
#  ('Саксаганського', 'Голосіївський, Печерський, Шевченківський', 168535.7),
#  ('Дніпровська', 'Оболонський', 135000),
#  ('Ділова', 'Голосіївський, Печерський', 120000),
#  ('Ревуцького', 'Дарницький', 98000),
#  ('Введенська', 'Подільський', 65000),
#  ('Виноградний', 'Печерський', 125000),
#  ('Кайсарова', "Голосіївський,Солом'янський", 48000),
#  ('Дніпровська', 'Оболонський', 84000),
#  ('Ділова', 'Голосіївський, Печерський', 175000),
#  ('Бориспільська', 'Дарницький', 63000),
#  ('Болсуновська', 'Печерський', 390000),
#  ('Науки', 'Голосіївський', 118000),
#  ('Метрологічна', 'Голосіївський', 159990),
#  ('Дружби Народів', 'Печерський', 85000),
#  ('Кримська', 'Голосіївський', 35000),
#  ('Новопольова', "Солом'янський", 63000),
#  ('Дніпровська', 'Оболонський', 60000),
#  ('Перемоги', 'Святошинський', 130000),
#  ('Перемоги', 'Шевченківський', 130000),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 130000),
#  ('Братиславська', 'Деснянський, Дніпровський', 46998),
#  ('Трускавецька', 'Дарницький', 298000),
#  ('Каховська', 'Дніпровський', 43100),
#  ('Голосіївська', 'Голосіївський', 110000),
#  ('Голосіївська', 'Голосіївський', 110000),
#  ('Тираспольська', 'Подільський', 47000),
#  ('Лаврська', 'Печерський', 90000),
#  ('Правди', 'Подільський', 44980),
#  ('Йорданська', 'Оболонський', 73860),
#  ('Регенераторна', 'Дніпровський', 135000),
#  ('Зарічна', 'Дарницький', 120000),
#  ('Курнатовського', 'Дніпровський, Деснянський', 90000),
#  ('Інститутська', 'Печерський', 187000),
#  ('Старонаводницька', 'Печерський', 140000),
#  ('Заньковецької', 'Печерський', 230000),
#  ('Кудрявська', 'Шевченківський', 178000),
#  ('Милославська', 'Деснянський', 33000),
#  ('Героїв Дніпра', 'Оболонський', 145000),
#  ('Каховська', 'Дніпровський', 118000),
#  ('Каховська', 'Дніпровський', 41000),
#  ('Вишняківська', 'Дарницький', 59899),
#  ('Причальна', 'Дарницький', 49500),
#  ('Болсуновська', 'Печерський', 275000),
#  ('Повітрофлотський', "Шевченківський, Солом'янський", 93000),
#  ('Драгоманова', 'Дарницький', 87500),
#  ('Дніпровська', 'Оболонський', 900000),
#  ('Правди', 'Подільський', 67000),
#  ('Малопідвальна', 'Шевченківський', 90000),
#  ('Зарічна', 'Дарницький', 104000),
#  ('Предславинська', 'Печерський', 190000),
#  ('Лабораторний', 'Печерський', 680000),
#  ('Дніпровська', 'Оболонський', 85000),
#  ('Клеманська', 'Дарницький', 35600),
#  ('Саперне Поле', 'Печерський', 530000),
#  ('Героїв Сталінграда', 'Оболонський', 229000),
#  ('Дніпровська', 'Оболонський', 117000),
#  ('Тарасівська', 'Голосіївський', 110000),
#  ('Краківська', 'Дніпровський', 92900),
#  ('Юнацька', 'Святошинський', 77500),
#  ('Юнацька', "Солом'янський", 77500),
#  ('Клеманська', 'Дарницький', 40500),
#  ('Героїв Сталінграда', 'Оболонський', 136000),
#  ('Драгоманова', 'Дарницький', 125000),
#  ('Маяковського', 'Деснянський', 57000),
#  ('Дмитрівська', 'Подільський', 170000),
#  ('Дмитрівська', 'Шевченківський', 170000),
#  ('Драгоманова', 'Дарницький', 92000),
#  ('Милославська', 'Деснянський', 45500),
#  ('Перемоги', 'Святошинський', 130000),
#  ('Перемоги', 'Шевченківський', 130000),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 130000),
#  ('Миропільська', 'Деснянський, Дніпровський', 84999),
#  ('Юнацька', 'Святошинський', 129999),
#  ('Юнацька', "Солом'янський", 129999),
#  ('Вишгородська', 'Подільський, Оболонський', 70000),
#  ('Жолудєва', 'Святошинський', 36000),
#  ('Павлівська', 'Шевченківський', 210000),
#  ('Голосіївський', 'Голосіївський', 85900),
#  ('Голосіївський', 'Голосіївський', 85900),
#  ('Осокорська', 'Дарницький', 108000),
#  ('Вишгородська', 'Подільський, Оболонський', 120000),
#  ('Героїв Сталінграда', 'Оболонський', 145000),
#  ('Максимовича', 'Святошинський', 50700),
#  ('Зарічна', 'Дарницький', 185000),
#  ('Голосіївська', 'Голосіївський', 152000),
#  ('Голосіївська', 'Голосіївський', 152000),
#  ('Ясинуватський', 'Голосіївський', 92000),
#  ('Правди', 'Подільський', 80000),
#  ('Велика Васильківська', 'Голосіївський, Шевченківський, Печерський', 480000),
#  ('Голосіївський', 'Голосіївський', 59000),
#  ('Голосіївський', 'Голосіївський', 59000),
#  ('Центральна', 'Дніпровський', 86860),
#  ('Центральна', 'Оболонський', 86860),
#  ('Центральна', 'Шевченківський', 86860),
#  ('Ясинуватський', 'Голосіївський', 97000),
#  ('Райдужна', 'Дніпровський', 55000),
#  ('Ломоносова', 'Голосіївський', 138000),
#  ('Гусовського', 'Печерський', 284000),
#  ('Багговутівська', 'Шевченківський', 49899),
#  ('Дружби Народів', 'Печерський', 95000),
#  ('Героїв Севастополя', "Солом'янський", 185000),
#  ('Саперне Поле', 'Печерський', 620000),
#  ('Балтійський', 'Оболонський', 48700),
#  ('Кудрявська', 'Шевченківський', 234000),
#  ('Перемоги', 'Святошинський', 135000),
#  ('Перемоги', 'Шевченківський', 135000),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 135000),
#  ('Німанська', 'Печерський', 130000),
#  ('Каховська', 'Дніпровський', 54100),
#  ('Малопідвальна', 'Шевченківський', 239000),
#  ('Берковецька', 'Святошинський', 41187),
#  ('Антоновича', 'Голосіївський, Печерський', 740000),
#  ('Микільсько-Слобідська', 'Дніпровський', 126000),
#  ('Правди', 'Подільський', 80000),
#  ('Олевська', 'Святошинський', 100000),
#  ('Освіти', "Солом'янський", 120000),
#  ('Дніпровська', 'Оболонський', 135000),
#  ('Каховська', 'Дніпровський', 70500),
#  ('Ушинського', "Солом'янський", 87000),
#  ('Ушинського', "Солом'янський", 87000),
#  ('Урлівська', 'Дарницький', 185000),
#  ('Світлицького', 'Подільський', 49860),
#  ('Дніпровська', 'Оболонський', 100000),
#  ('Микільсько-Слобідська', 'Дніпровський', 152000),
#  ('Героїв Сталінграда', 'Оболонський', 280000),
#  ('Дніпровська', 'Оболонський', 85000),
#  ('Драгоманова', 'Дарницький', 67000),
#  ('Саперне Поле', 'Печерський', 420000),
#  ('Голосіївський', 'Голосіївський', 63000),
#  ('Голосіївський', 'Голосіївський', 63000),
#  ('Глибочицька', 'Шевченківський', 100000),
#  ('Багговутівська', 'Шевченківський', 165000),
#  ('Саксаганського', 'Голосіївський, Печерський, Шевченківський', 150000),
#  ('Йорданська', 'Оболонський', 73860),
#  ('Саперне Поле', 'Печерський', 295000),
#  ('Багговутівська', 'Шевченківський', 100000),
#  ('Набережно-Рибальська', 'Подільський', 122000),
#  ('Саксаганського', 'Голосіївський, Печерський, Шевченківський', 145000),
#  ('Протасів Яр', "Солом'янський", 143000),
#  ('Німанська', 'Печерський', 62000),
#  ('Зодчих', 'Святошинський', 38000),
#  ('Шовковична', 'Печерський', 229000),
#  ('Новопольова', "Солом'янський", 70000),
#  ('Визволителів', 'Дніпровський', 45000),
#  ('Сонячна', 'Дніпровський', 70000),
#  ('Сонячна', 'Шевченківський', 70000),
#  ('Бульварно-Кудрявська', 'Шевченківський', 104700),
#  ('Кайсарова', "Голосіївський,Солом'янський", 37000),
#  ('Дніпровська', 'Оболонський', 85000),
#  ('Перова', 'Дніпровський', 46000),
#  ('Саперно-Слобідська', 'Голосіївський', 120000),
#  ('Антоновича', 'Голосіївський, Печерський', 250000),
#  ('Богданівська', "Солом'янський", 185000),
#  ('Ревуцького', 'Дарницький', 52500),
#  ('Саперне Поле', 'Печерський', 540000),
#  ('Богатирська', 'Оболонський', 68800),
#  ('Білоруська', 'Шевченківський', 120000),
#  ('Регенераторна', 'Дніпровський', 94000),
#  ('Вишняківська', 'Дарницький', 65500),
#  ('Правди', 'Подільський', 52500),
#  ('Кольцова', 'Святошинський', 64980),
#  ('Воскресенська', 'Дніпровський', 115000),
#  ('Голосіївський', 'Голосіївський', 484000),
#  ('Голосіївський', 'Голосіївський', 484000),
#  ('Комбінатна', 'Дніпровський', 79000),
#  ('Салютна', 'Шевченківський', 45000),
#  ('Саперне Поле', 'Печерський', 128000),
#  ('Лабораторна', 'Голосіївський, Печерський', 95000),
#  ('Драгоманова', 'Дарницький', 77000),
#  ('Кудрявська', 'Шевченківський', 330000),
#  ('Краківська', 'Дніпровський', 83000),
#  ('Кольцова', 'Святошинський', 105000),
#  ('Антоновича', 'Голосіївський, Печерський', 225000),
#  ('Оболонський', 'Оболонський', 195000),
#  ('Зарічна', 'Дарницький', 185000),
#  ('Дніпровська', 'Оболонський', 210000),
#  ('Коломийський', 'Голосіївський', 135000),
#  ('Правди', 'Подільський', 84000),
#  ('Каховська', 'Дніпровський', 160000),
#  ('Правди', 'Подільський', 53000),
#  ('Перемоги', 'Святошинський', 90900),
#  ('Перемоги', 'Шевченківський', 90900),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 90900),
#  ('Срібнокільська', 'Дарницький', 980000),
#  ('Перемоги', 'Святошинський', 91260),
#  ('Перемоги', 'Шевченківський', 91260),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 91260),
#  ('Урлівська', 'Дарницький', 118000),
#  ('Максимовича', 'Святошинський', 79700),
#  ('Дніпровська', 'Оболонський', 68500),
#  ('Кубанської України', 'Деснянський', 64500),
#  ('Дніпровська', 'Оболонський', 100000),
#  ('Богатирська', 'Оболонський', 52000),
#  ('Оболонський', 'Оболонський', 50000),
#  ('Правди', 'Подільський', 84000),
#  ('Центральна', 'Дніпровський', 69000),
#  ('Центральна', 'Оболонський', 69000),
#  ('Центральна', 'Шевченківський', 69000),
#  ('Преображенська', "Солом'янський", 70000),
#  ('Велика Васильківська', 'Голосіївський, Шевченківський, Печерський', 170000),
#  ('Васильківська', 'Голосіївський', 46500),
#  ('Богатирська', 'Оболонський', 89332.9),
#  ('Редутна', 'Печерський', 1035900),
#  ('Мінський', 'Оболонський', 43000),
#  ('Мінський', 'Подільський', 43000),
#  ('Княжий Затон', 'Дарницький', 235000),
#  ('Герцена', 'Шевченківський', 105900),
#  ('Герцена', 'Шевченківський', 105900),
#  ('Герцена', 'Шевченківський', 105900),
#  ('Балтійський', 'Оболонський', 49700),
#  ('Голосіївська', 'Голосіївський', 225000),
#  ('Голосіївська', 'Голосіївський', 225000),
#  ('Саперне Поле', 'Печерський', 205000),
#  ('Паторжинського', 'Шевченківський', 777500),
#  ('Дніпровська', 'Оболонський', 100500),
#  ('Електриків', 'Подільський', 149000),
#  ('Електриків', 'Подільський', 149000),
#  ("Солом'янська", "Солом'янський", 95000),
#  ("Солом'янська", "Солом'янський", 95000),
#  ('Шевченка', 'Дарницький', 159000),
#  ('Шевченка', 'Дарницький', 159000),
#  ('Шевченка', 'Деснянський', 159000),
#  ('Шевченка', "Солом'янський", 159000),
#  ('Шевченка', "Солом'янський", 159000),
#  ('Озерна', 'Дарницький', 68000),
#  ('Озерна', 'Оболонський', 68000),
#  ('Озерна', 'Святошинський (СТ "Нивки")', 68000),
#  ('Озерна', "Солом'янський", 68000),
#  ('Голосіївський', 'Голосіївський', 229000),
#  ('Голосіївський', 'Голосіївський', 229000),
#  ('Борщагівська', "Солом'янський, Шевченківський ", 66500),
#  ('Шевченка', 'Дарницький', 480000),
#  ('Шевченка', 'Дарницький', 480000),
#  ('Шевченка', 'Деснянський', 480000),
#  ('Шевченка', "Солом'янський", 480000),
#  ('Шевченка', "Солом'янський", 480000),
#  ('Максимовича', 'Святошинський', 74000),
#  ('Ковальський', "Солом'янський", 175000),
#  ('Мічуріна', 'Деснянський', 3200000),
#  ('Мічуріна', 'Оболонський', 3200000),
#  ('Мічуріна', 'Печерський', 3200000),
#  ('Мічуріна', 'Печерський', 3200000),
#  ('Мічуріна', "Солом'янський", 3200000),
#  ('Балтійський', 'Оболонський', 63000),
#  ('Азербайджанська', 'Дніпровський', 85000),
#  ('Зарічна', 'Дарницький', 130032),
#  ('Правди', 'Подільський', 50000),
#  ('Урлівська', 'Дарницький', 114900),
#  ('Бориспільська', 'Дарницький', 41500),
#  ('Бориспільська', 'Дарницький', 48000),
#  ('Ентузіастів', 'Дніпровський', 59899),
#  ('Малоземельна', 'Дарницький', 83000),
#  ('Саксаганського', 'Голосіївський, Печерський, Шевченківський', 335000),
#  ('Героїв Сталінграда', 'Оболонський', 98500),
#  ('Зодчих', 'Святошинський', 58000),
#  ('Старонаводницька', 'Печерський', 345000),
#  ('Правди', 'Подільський', 58000),
#  ('Антоновича', 'Голосіївський, Печерський', 290000),
#  ('Деревлянська', 'Шевченківський', 135000),
#  ('Васильченка', "Солом'янський", 107000),
#  ('Предславинська', 'Печерський', 139990),
#  ('Крайня', 'Деснянський', 31000),
#  ('Милославська', 'Деснянський', 58000),
#  ('Воскресенська', 'Дніпровський', 145000),
#  ('Дніпровська', 'Оболонський', 230000),
#  ('Пушкінська', 'Шевченківський', 240000),
#  ('Набережно-Корчуватська', 'Голосіївський', 65280),
#  ('Зарічна', 'Дарницький', 150000),
#  ('Тургенєвська', 'Шевченківський', 499990),
#  ('Зарічна', 'Дарницький', 140000),
#  ('Метрологічна', 'Голосіївський', 68900),
#  ('Йорданська', 'Оболонський', 73860),
#  ('Кольцова', 'Святошинський', 49500),
#  ('Максимовича', 'Святошинський', 138000),
#  ('Науки', 'Голосіївський', 55500),
#  ('Саперно-Слобідська', 'Голосіївський', 206000),
#  ('Шовковична', 'Печерський', 110000),
#  ('Трускавецька', 'Дарницький', 250000),
#  ('Повітрофлотський', "Шевченківський, Солом'янський", 53000),
#  ('Перемоги', 'Святошинський', 86000),
#  ('Перемоги', 'Шевченківський', 86000),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 86000),
#  ('Зарічна', 'Дарницький', 73000),
#  ('Будищанська', 'Деснянський', 45000),
#  ('Жилянська', 'Печерський, Голосіївський, Шевченківський', 115000),
#  ('Комбінатна', 'Дніпровський', 79000),
#  ('Ревуцького', 'Дарницький', 88000),
#  ('Драгоманова', 'Дарницький', 95000),
#  ('Преображенська', "Солом'янський", 128000),
#  ('Депутатська', 'Святошинський', 68000),
#  ('Багговутівська', 'Шевченківський', 85000),
#  ('Коперніка', 'Шевченківський', 250000),
#  ('Васильківська', 'Голосіївський', 127000),
#  ('Глибочицька', 'Шевченківський', 98000),
#  ('Шовковична', 'Печерський', 229000),
#  ('Дніпровська', 'Оболонський', 115000),
#  ('Антоновича', 'Голосіївський, Печерський', 90000),
#  ('Славгородська', 'Дарницький', 53000),
#  ('Срібнокільська', 'Дарницький', 205000),
#  ('Саперне Поле', 'Печерський', 205000),
#  ('Мечнікова', 'Печерський', 120000),
#  ('Героїв Сталінграда', 'Оболонський', 150000),
#  ('Рибальська', 'Печерський', 285000),
#  ('Березова', "Солом'янський", 72500),
#  ('Саперне Поле', 'Печерський', 750000),
#  ('Антоновича', 'Голосіївський, Печерський', 493000),
#  ('Лейпцизька', 'Печерський', 247000),
#  ('Драгоманова', 'Дарницький', 90000),
#  ('Січових Стрільців', 'Шевченківський', 105000),
#  ('Райдужна', 'Дніпровський', 78000),
#  ('Тургенєвська', 'Шевченківський', 494000),
#  ('Васильківська', 'Голосіївський', 46500),
#  ('Милославська', 'Деснянський', 47500),
#  ('Метрологічна', 'Голосіївський', 100000),
#  ('Деміївська', 'Голосіївський', 103000),
#  ('Деміївська', 'Голосіївський', 103000),
#  ('Перемоги', 'Святошинський', 95000),
#  ('Перемоги', 'Шевченківський', 95000),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 95000),
#  ('Вишгородська', 'Подільський, Оболонський', 76800),
#  ('Перемоги', 'Святошинський', 302200),
#  ('Перемоги', 'Шевченківський', 302200),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 302200),
#  ('Балтійський', 'Оболонський', 63500),
#  ('Звіринецька', 'Печерський', 550000),
#  ('Ревуцького', 'Дарницький', 98700),
#  ('Правди', 'Подільський', 80000),
#  ('Милославська', 'Деснянський', 35000),
#  ('Новгородська', "Солом'янський", 36000),
#  ('Канівська', 'Подільський', 220000),
#  ('Максимовича', 'Святошинський', 109000),
#  ('Тираспольська', 'Подільський', 60000),
#  ('Саксаганського', 'Голосіївський, Печерський, Шевченківський', 15700000),
#  ('Тираспольська', 'Подільський', 45000),
#  ('Зарічна', 'Дарницький', 160000),
#  ('Світлицького', 'Подільський', 59000),
#  ('Каховська', 'Дніпровський', 81000),
#  ('Глибочицька', 'Шевченківський', 67000),
#  ('Балтійський', 'Оболонський', 54500),
#  ('Антоновича', 'Голосіївський, Печерський', 232000),
#  ('Ревуцького', 'Дарницький', 55000),
#  ('Драгоманова', 'Дарницький', 70000),
#  ('Голосіївська', 'Голосіївський', 100000),
#  ('Голосіївська', 'Голосіївський', 100000),
#  ('Оболонський', 'Оболонський', 1010000),
#  ('Миколи Голего', "Солом'янський", 45000),
#  ('Дніпровська', 'Оболонський', 80000),
#  ('Назарівська', 'Шевченківський', 620000),
#  ('Гоголівська', 'Шевченківський', 250500),
#  ('Дорогожицька', 'Шевченківський', 39000),
#  ('Петропавлівська', 'Оболонський', 30970),
#  ('Петропавлівська', 'Подільський', 30970),
#  ('Ушинського', "Солом'янський", 63900),
#  ('Ушинського', "Солом'янський", 63900),
#  ('Польова', 'Дарницький', 81000),
#  ('Польова', 'Деснянський', 81000),
#  ('Польова', "Солом'янський", 81000),
#  ('Саперне Поле', 'Печерський', 219000),
#  ('Антоновича', 'Голосіївський, Печерський', 499000),
#  ('Толстого', 'Дарницький', 310000),
#  ('Дружби Народів', 'Печерський', 99800),
#  ('Оболонський', 'Оболонський', 130000),
#  ('Багговутівська', 'Шевченківський', 70000),
#  ('Володимирська', 'Голосіївський, Шевченківський', 199000),
#  ('Московська', 'Печерський', 275000),
#  ('Московська', "Солом'янський", 275000),
#  ('Жмеринська', 'Святошинський', 38000),
#  ('Лабораторний', 'Печерський', 330000),
#  ('Інститутська', 'Печерський', 1500000),
#  ('Хрещатик', 'Печерський, Шевченківський', 295000),
#  ('Дніпровська', 'Оболонський', 62000),
#  ('Осокорська', 'Дарницький', 108000),
#  ('Саперне Поле', 'Печерський', 255000),
#  ('Срібнокільська', 'Дарницький', 139000),
#  ('Чоколівський', "Солом'янський", 115000),
#  ('Звіринецька', 'Печерський', 104000),
#  ('Вишгородська', 'Подільський, Оболонський', 85000),
#  ('Героїв Сталінграда', 'Оболонський', 229000),
#  ('Будівельників', 'Деснянський', 65000),
#  ('Будівельників', 'Дніпровський', 65000),
#  ('Будівельників', 'Дніпровський', 65000),
#  ('Будівельників', 'Святошинський', 65000),
#  ('Урлівська', 'Дарницький', 105000),
#  ('Сормовська', 'Дарницький', 57000),
#  ('Правди', 'Подільський', 65000),
#  ('Верховинна', 'Святошинський', 98000),
#  ('Велика Васильківська', 'Голосіївський, Шевченківський, Печерський', 115000),
#  ('Кропивницького', 'Печерський', 435000),
#  ('Трускавецька', 'Дарницький', 100000),
#  ('Голосіївська', 'Голосіївський', 110000),
#  ('Голосіївська', 'Голосіївський', 110000),
#  ('Юнацька', 'Святошинський', 125000),
#  ('Юнацька', "Солом'янський", 125000),
#  ('Максимовича', 'Святошинський', 89000),
#  ('Багговутівська', 'Шевченківський', 70000),
#  ('Костанайська', 'Голосіївський', 84000),
#  ('Срібнокільська', 'Дарницький', 160000),
#  ('Гусовського', 'Печерський', 61000),
#  ('Драгоманова', 'Дарницький', 120000),
#  ('Дніпровська', 'Оболонський', 250000),
#  ('Перемоги', 'Святошинський', 113261),
#  ('Перемоги', 'Шевченківський', 113261),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 113261),
#  ('Дніпровська', 'Оболонський', 108000),
#  ('Волгоградська', 'Деснянський', 47000),
#  ('Волгоградська', "Солом'янський", 47000),
#  ('Новопольова', "Солом'янський", 57000),
#  ('Драгоманова', 'Дарницький', 135482.1),
#  ('Лейпцизька', 'Печерський', 150000),
#  ('Глибочицька', 'Шевченківський', 285000),
#  ('Салютна', 'Шевченківський', 115000),
#  ('Метрологічна', 'Голосіївський', 45900),
#  ('Північно-Сирецька', 'Подільський', 60000),
#  ('Правди', 'Подільський', 115000),
#  ('Лейпцизька', 'Печерський', 183693.7),
#  ('Басейна', 'Печерський, Шевченківський', 200000),
#  ('Бережанська', 'Оболонський', 39500),
#  ('Перемоги', 'Святошинський', 80000),
#  ('Перемоги', 'Шевченківський', 80000),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 80000),
#  ('Антоновича', 'Голосіївський, Печерський', 320000),
#  ('Перемоги', 'Святошинський', 101000),
#  ('Перемоги', 'Шевченківський', 101000),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 101000),
#  ('Ковпака', 'Голосіївський, Печерський', 849000),
#  ('Русанівський', 'Дніпровський', 85000),
#  ('Празька', 'Дніпровський', 33900),
#  ('Балтійський', 'Оболонський', 40000),
#  ('Білоруська', 'Шевченківський', 104000),
#  ('Драгоманова', 'Дарницький', 75000),
#  ('Новогоспітальна', 'Печерський', 58000),
#  ('Оболонський', 'Оболонський', 160000),
#  ('Щекавицька', 'Подільський', 200714.3),
#  ('Щекавицька', 'Подільський', 200714.3),
#  ('Пожарського', 'Деснянський', 65000),
#  ('Пожарського', 'Дніпровський', 65000),
#  ('Полкова', 'Подільський', 74000),
#  ('Павлівська', 'Шевченківський', 180000),
#  ('Іскрівська', "Солом'янський", 42900),
#  ('Максимовича', 'Святошинський', 95000),
#  ('Теремківська', 'Голосіївський', 115000),
#  ('Осокорська', 'Дарницький', 113300),
#  ('Дмитрівська', 'Подільський', 268000),
#  ('Дмитрівська', 'Шевченківський', 268000),
#  ('Регенераторна', 'Дніпровський', 146000),
#  ('Глибочицька', 'Шевченківський', 495000),
#  ('Героїв Сталінграда', 'Оболонський', 275000),
#  ('Борщагівська', "Солом'янський, Шевченківський ", 73500),
#  ('Ревуцького', 'Дарницький', 57000),
#  ('Юнацька', 'Святошинський', 121860),
#  ('Юнацька', "Солом'янський", 121860),
#  ('Автозаводська', 'Оболонський', 39000),
#  ('Саксаганського', 'Голосіївський, Печерський, Шевченківський', 210000),
#  ('Зарічна', 'Дарницький', 139900),
#  ('Героїв Сталінграда', 'Оболонський', 76000),
#  ('Вишняківська', 'Дарницький', 65500),
#  ('Здолбунівська', 'Дарницький', 115000),
#  ('Мечнікова', 'Печерський', 3210000),
#  ('Максимовича', 'Святошинський', 127900),
#  ('Багговутівська', 'Шевченківський', 75000),
#  ('Шолуденка', 'Шевченківський', 90005),
#  ('Щекавицька', 'Подільський', 284999),
#  ('Щекавицька', 'Подільський', 284999),
#  ('Перемоги', 'Святошинський', 91000),
#  ('Перемоги', 'Шевченківський', 91000),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 91000),
#  ('Перемоги', 'Святошинський', 89000),
#  ('Перемоги', 'Шевченківський', 89000),
#  ('Перемоги', "Шевченківський, Святошинський, Солом'янський", 89000),
#  ('Велика Васильківська', 'Голосіївський, Шевченківський, Печерський', 170000),
#  ('Вишгородська', 'Подільський, Оболонський', 46500)]

# %%
# створити np-масив з списку `result_list`
result_arr = np.array(result_list)

# %%
np.mean(np.array([1,2,3]))
# Out:
# 2.0

# %%
result_dict = {
    "кількість спостережень"   : len(result_arr),
    "кількість пустих значень" : np.count_nonzero(result_arr[:,2] == 0),
    "середній бал"             : np.mean(result_arr[:,2]),
    "максимальний бал"         : np.max(result_arr[:,2]),
    "мінімальний бал"          : np.min(result_arr[:,2]),
    "стандартне відхилення"    : np.std(result_arr[:,2]),
    "розмах вариації"          : result_dict["максимальний бал"] - result_dict["мінімальний бал"] 
    }
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-b72b1a34e2d7> in <module>
#       2     "кількість спостережень"   : len(result_arr),
#       3     "кількість пустих значень" : np.count_nonzero(result_arr[:,2] == 0),
# ----> 4     "середній бал"             : np.mean(result_arr[:,2]),
#       5     "максимальний бал"         : np.max(result_arr[:,2]),
#       6     "мінімальний бал"          : np.min(result_arr[:,2]),
#
# /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3116
#    3117     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3118                           out=out, **kwargs)
#    3119
#    3120
#
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      73             is_float16_result = True
#      74
# ---> 75     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      76     if isinstance(ret, mu.ndarray):
#      77         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %%
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('street_district');").fetchall()
# Out:
# [('street',), ('type',), ('district',)]

# %%
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('street_flat_propery');").fetchall()
# Out:
# [('price',), ('street',)]

# %%
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('result');").fetchall()
# Out:
# [('district',), ('street',), ('price',)]
